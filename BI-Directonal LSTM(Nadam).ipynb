# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import array
from numpy import hstack

# %%
df=pd.read_csv("/content/drive/MyDrive/Minor/Minor project datasets/Main_dataset/air_quality_data-4.csv")

# %%
df_main=df[["datetime","pm10","pm25","co","no2","o3","so2","aqi"]]

# %%
df_main
# Out:
#            datetime  pm10   pm25     co   no2    o3   so2  aqi
# 0     2023-01-30:18  57.0  42.75  198.0   5.0  87.0  20.0  153
# 1     2023-01-30:17  54.3  40.75  192.3   5.0  89.0  18.0  153
# 2     2023-01-30:16  51.7  38.75  186.7   5.0  91.0  16.0  153
# 3     2023-01-30:15  49.0  36.75  181.0   5.0  93.0  14.0  150
# 4     2023-01-30:14  46.3  34.75  172.7   3.7  99.3  12.3  137
# ...             ...   ...    ...    ...   ...   ...   ...  ...
# 5427  2023-08-05:22  15.0  12.00   89.0   7.7  37.3  17.7   50
# 5428  2023-08-05:21  16.0  12.00   92.0   8.0  39.0  18.0   87
# 5429  2023-08-05:20  18.0  13.50  100.3   9.0  39.0  18.3  104
# 5430  2023-08-05:19  20.0  15.00  108.7  10.0  39.0  18.7   80
# 5431  2023-08-05:18  22.0  19.00  117.0  11.0  39.0  19.0   65
#
# [5432 rows x 8 columns]

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5432 entries, 0 to 5431
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  5432 non-null   object
#  1   pm10      5432 non-null   float64
#  2   pm25      5432 non-null   float64
#  3   co        5432 non-null   float64
#  4   no2       5432 non-null   float64
#  5   o3        5432 non-null   float64
#  6   so2       5432 non-null   float64
#  7   aqi       5432 non-null   int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 339.6+ KB

# %%
df_main .set_index('datetime')[['pm10', 'pm25', 'co', 'no2', 'o3','so2']][::15].plot (subplots=True, figsize=(20, 20),kind='line')
# Out:
# array([<Axes: xlabel='datetime'>, <Axes: xlabel='datetime'>,
#        <Axes: xlabel='datetime'>, <Axes: xlabel='datetime'>,
#        <Axes: xlabel='datetime'>, <Axes: xlabel='datetime'>], dtype=object)

# %%
new = df_main["datetime"].str.split(":", n=1, expand=True)
df_main["date"] = new[0]
df_main["time"] = new[1]

# Combine "date" and "time" into a new "datetime" column
df_main['datetime'] = df_main.date + " " + df_main.time

# Drop "date" and "time" columns
df_main = df_main.drop(['date', 'time'], axis=1)  # Specify the 'axis' parameter
# Out:
# <ipython-input-50-1be7e3b8ebe9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main["date"] = new[0]
# <ipython-input-50-1be7e3b8ebe9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main["time"] = new[1]
# <ipython-input-50-1be7e3b8ebe9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main['datetime'] = df_main.date + " " + df_main.time

# %%
df_main
# Out:
#            datetime  pm10   pm25     co   no2    o3   so2  aqi
# 0     2023-01-30 18  57.0  42.75  198.0   5.0  87.0  20.0  153
# 1     2023-01-30 17  54.3  40.75  192.3   5.0  89.0  18.0  153
# 2     2023-01-30 16  51.7  38.75  186.7   5.0  91.0  16.0  153
# 3     2023-01-30 15  49.0  36.75  181.0   5.0  93.0  14.0  150
# 4     2023-01-30 14  46.3  34.75  172.7   3.7  99.3  12.3  137
# ...             ...   ...    ...    ...   ...   ...   ...  ...
# 5427  2023-08-05 22  15.0  12.00   89.0   7.7  37.3  17.7   50
# 5428  2023-08-05 21  16.0  12.00   92.0   8.0  39.0  18.0   87
# 5429  2023-08-05 20  18.0  13.50  100.3   9.0  39.0  18.3  104
# 5430  2023-08-05 19  20.0  15.00  108.7  10.0  39.0  18.7   80
# 5431  2023-08-05 18  22.0  19.00  117.0  11.0  39.0  19.0   65
#
# [5432 rows x 8 columns]

# %%
df_main.datetime = pd.to_datetime(df_main.datetime)

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5432 entries, 0 to 5431
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  5432 non-null   datetime64[ns]
#  1   pm10      5432 non-null   float64
#  2   pm25      5432 non-null   float64
#  3   co        5432 non-null   float64
#  4   no2       5432 non-null   float64
#  5   o3        5432 non-null   float64
#  6   so2       5432 non-null   float64
#  7   aqi       5432 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 339.6 KB

# %%
df_main = df_main.set_index('datetime')

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5432 entries, 2023-01-30 18:00:00 to 2023-08-05 18:00:00
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pm10    5432 non-null   float64
#  1   pm25    5432 non-null   float64
#  2   co      5432 non-null   float64
#  3   no2     5432 non-null   float64
#  4   o3      5432 non-null   float64
#  5   so2     5432 non-null   float64
#  6   aqi     5432 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 339.5 KB

# %%
df_main = df_main.interpolate()

# %%
df_main
# Out:
#                      pm10   pm25     co   no2    o3   so2  aqi
# datetime
# 2023-01-30 18:00:00  57.0  42.75  198.0   5.0  87.0  20.0  153
# 2023-01-30 17:00:00  54.3  40.75  192.3   5.0  89.0  18.0  153
# 2023-01-30 16:00:00  51.7  38.75  186.7   5.0  91.0  16.0  153
# 2023-01-30 15:00:00  49.0  36.75  181.0   5.0  93.0  14.0  150
# 2023-01-30 14:00:00  46.3  34.75  172.7   3.7  99.3  12.3  137
# ...                   ...    ...    ...   ...   ...   ...  ...
# 2023-08-05 22:00:00  15.0  12.00   89.0   7.7  37.3  17.7   50
# 2023-08-05 21:00:00  16.0  12.00   92.0   8.0  39.0  18.0   87
# 2023-08-05 20:00:00  18.0  13.50  100.3   9.0  39.0  18.3  104
# 2023-08-05 19:00:00  20.0  15.00  108.7  10.0  39.0  18.7   80
# 2023-08-05 18:00:00  22.0  19.00  117.0  11.0  39.0  19.0   65
#
# [5432 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# Split a multivariate sequence into samples
def sequences(seq,data_in,data_out):
	A,B = list(), list()
	for i in range(len(seq)):
		# find the end of this pattern
		pattern_in = i + data_in
		pattern_out= pattern_in + data_out
		# check if we are beyond the dataset
		if pattern_out > len(seq):
			break
		# gather input and output parts of the pattern
		seq_in, seq_out = seq[i:pattern_in, :], seq[pattern_in:pattern_out, :]
		A.append(seq_in)
		B.append(seq_out)
	return array(A), array(B)

# %%
complete_dataset = len(df_main)

# %%
df_train = df_main[:int(complete_dataset*0.76)]

# %%
df_test = df_main[int(complete_dataset*0.76):complete_dataset]

# %%
normalize = MinMaxScaler()

# %%
df_train_normalize= normalize.fit_transform(df_train)

# %%
df_test_normalize = normalize.fit_transform(df_test)

# %%
df_train.shape
# Out:
# (4128, 7)

# %%
df_train.shape[0]/24
# Out:
# 172.0

# %%
df_test.shape
# Out:
# (1304, 7)

# %%
df_test.shape[0]/24
# Out:
# 54.333333333333336

# %%
data_in=6

# %%
data_out=3

# %%
x_train, y_train = sequences(df_train_normalize, data_in, data_out)

# %%
x_test, y_test = sequences(df_test_normalize, data_in, data_out)

# %%
columns= x_train.shape[2]

# %%
print(x_train[0])
# Out:
# [[0.38980617 0.33669355 0.13459621 0.04545455 0.43617021 0.0972973
#   0.46779661]
#  [0.37042355 0.32056452 0.12891326 0.04545455 0.44680851 0.08648649
#   0.46779661]
#  [0.35175879 0.30443548 0.12333001 0.04545455 0.45744681 0.07567568
#   0.46779661]
#  [0.33237617 0.28830645 0.11764706 0.04545455 0.46808511 0.06486486
#   0.45762712]
#  [0.31299354 0.27217742 0.10937188 0.03068182 0.50159574 0.05567568
#   0.41355932]
#  [0.29432879 0.25604839 0.10099701 0.01477273 0.5356383  0.04702703
#   0.36610169]]

# %%
print(y_train[0])
# Out:
# [[0.27494616 0.23991935 0.09272183 0.         0.56914894 0.03783784
#   0.38644068]
#  [0.28930366 0.25201613 0.09371884 0.         0.56010638 0.03945946
#   0.42033898]
#  [0.30366116 0.33870968 0.09471585 0.         0.55159574 0.04162162
#   0.35932203]]

# %%
columns
# Out:
# 7

# %%
x_train.shape
# Out:
# (4120, 6, 7)

# %%
y_train.shape
# Out:
# (4120, 3, 7)

# %%
x_test.shape
# Out:
# (1296, 6, 7)

# %%
y_test.shape
# Out:
# (1296, 3, 7)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
import tensorflow as tf
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Dropout

# %%
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import RepeatVector, TimeDistributed, Dense

model = Sequential()
model.add(Bidirectional(LSTM(200, activation='relu', input_shape=(data_in, columns), return_sequences=True)))
model.add(Bidirectional(LSTM(200, activation='relu', return_sequences=False)))
model.add(RepeatVector(data_out))
model.add(Bidirectional(LSTM(200, activation='relu', return_sequences=True)))
model.add(TimeDistributed(Dense(columns)))

# %%
from tensorflow.keras import optimizers
epoch =75

model.compile(optimizer='nadam', loss='mse',metrics=[tf.metrics.MeanAbsoluteError()])

history = model.fit(x_train, y_train, epochs=epoch, validation_data=(x_test, y_test))
# Out:
# Epoch 1/75
# 129/129 [==============================] - 34s 175ms/step - loss: 0.0150 - mean_absolute_error: 0.0815 - val_loss: 0.0130 - val_mean_absolute_error: 0.0835
# Epoch 2/75
# 129/129 [==============================] - 20s 158ms/step - loss: 0.0051 - mean_absolute_error: 0.0487 - val_loss: 0.0090 - val_mean_absolute_error: 0.0691
# Epoch 3/75
# 129/129 [==============================] - 22s 168ms/step - loss: 0.0039 - mean_absolute_error: 0.0424 - val_loss: 0.0076 - val_mean_absolute_error: 0.0629
# Epoch 4/75
# 129/129 [==============================] - 23s 178ms/step - loss: 0.0035 - mean_absolute_error: 0.0397 - val_loss: 0.0076 - val_mean_absolute_error: 0.0624
# Epoch 5/75
# 129/129 [==============================] - 21s 164ms/step - loss: 0.0033 - mean_absolute_error: 0.0385 - val_loss: 0.0074 - val_mean_absolute_error: 0.0616
# Epoch 6/75
# 129/129 [==============================] - 22s 171ms/step - loss: 0.0031 - mean_absolute_error: 0.0368 - val_loss: 0.0072 - val_mean_absolute_error: 0.0606
# Epoch 7/75
# 129/129 [==============================] - 20s 157ms/step - loss: 0.0028 - mean_absolute_error: 0.0353 - val_loss: 0.0076 - val_mean_absolute_error: 0.0618
# Epoch 8/75
# 129/129 [==============================] - 28s 219ms/step - loss: 0.0027 - mean_absolute_error: 0.0341 - val_loss: 0.0072 - val_mean_absolute_error: 0.0595
# Epoch 9/75
# 129/129 [==============================] - 22s 168ms/step - loss: 0.0026 - mean_absolute_error: 0.0334 - val_loss: 0.0071 - val_mean_absolute_error: 0.0589
# Epoch 10/75
# 129/129 [==============================] - 21s 161ms/step - loss: 0.0025 - mean_absolute_error: 0.0328 - val_loss: 0.0070 - val_mean_absolute_error: 0.0589
# Epoch 11/75
# 129/129 [==============================] - 20s 156ms/step - loss: 0.0025 - mean_absolute_error: 0.0326 - val_loss: 0.0071 - val_mean_absolute_error: 0.0600
# Epoch 12/75
# 129/129 [==============================] - 22s 172ms/step - loss: 0.0023 - mean_absolute_error: 0.0313 - val_loss: 0.0067 - val_mean_absolute_error: 0.0575
# Epoch 13/75
# 129/129 [==============================] - 21s 163ms/step - loss: 0.0023 - mean_absolute_error: 0.0314 - val_loss: 0.0072 - val_mean_absolute_error: 0.0607
# Epoch 14/75
# 129/129 [==============================] - 22s 168ms/step - loss: 0.0023 - mean_absolute_error: 0.0308 - val_loss: 0.0066 - val_mean_absolute_error: 0.0575
# Epoch 15/75
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0023 - mean_absolute_error: 0.0309 - val_loss: 0.0065 - val_mean_absolute_error: 0.0560
# Epoch 16/75
# 129/129 [==============================] - 21s 160ms/step - loss: 0.0021 - mean_absolute_error: 0.0297 - val_loss: 0.0065 - val_mean_absolute_error: 0.0570
# Epoch 17/75
# 129/129 [==============================] - 23s 177ms/step - loss: 0.0021 - mean_absolute_error: 0.0291 - val_loss: 0.0068 - val_mean_absolute_error: 0.0575
# Epoch 18/75
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0022 - mean_absolute_error: 0.0300 - val_loss: 0.0071 - val_mean_absolute_error: 0.0593
# Epoch 19/75
# 129/129 [==============================] - 19s 147ms/step - loss: 0.0020 - mean_absolute_error: 0.0289 - val_loss: 0.0065 - val_mean_absolute_error: 0.0563
# Epoch 20/75
# 129/129 [==============================] - 21s 164ms/step - loss: 0.0020 - mean_absolute_error: 0.0288 - val_loss: 0.0080 - val_mean_absolute_error: 0.0646
# Epoch 21/75
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0020 - mean_absolute_error: 0.0288 - val_loss: 0.0064 - val_mean_absolute_error: 0.0554
# Epoch 22/75
# 129/129 [==============================] - 21s 160ms/step - loss: 0.0019 - mean_absolute_error: 0.0279 - val_loss: 0.0070 - val_mean_absolute_error: 0.0590
# Epoch 23/75
# 129/129 [==============================] - 20s 153ms/step - loss: 0.0019 - mean_absolute_error: 0.0282 - val_loss: 0.0063 - val_mean_absolute_error: 0.0561
# Epoch 24/75
# 129/129 [==============================] - 19s 147ms/step - loss: 0.0019 - mean_absolute_error: 0.0279 - val_loss: 0.0076 - val_mean_absolute_error: 0.0621
# Epoch 25/75
# 129/129 [==============================] - 20s 158ms/step - loss: 0.0019 - mean_absolute_error: 0.0278 - val_loss: 0.0067 - val_mean_absolute_error: 0.0581
# Epoch 26/75
# 129/129 [==============================] - 20s 157ms/step - loss: 0.0019 - mean_absolute_error: 0.0278 - val_loss: 0.0070 - val_mean_absolute_error: 0.0590
# Epoch 27/75
# 129/129 [==============================] - 20s 158ms/step - loss: 0.0018 - mean_absolute_error: 0.0275 - val_loss: 0.0063 - val_mean_absolute_error: 0.0552
# Epoch 28/75
# 129/129 [==============================] - 22s 170ms/step - loss: 0.0018 - mean_absolute_error: 0.0271 - val_loss: 0.0069 - val_mean_absolute_error: 0.0582
# Epoch 29/75
# 129/129 [==============================] - 20s 154ms/step - loss: 0.0018 - mean_absolute_error: 0.0277 - val_loss: 0.0071 - val_mean_absolute_error: 0.0584
# Epoch 30/75
# 129/129 [==============================] - 21s 163ms/step - loss: 0.0017 - mean_absolute_error: 0.0268 - val_loss: 0.0074 - val_mean_absolute_error: 0.0612
# Epoch 31/75
# 129/129 [==============================] - 20s 157ms/step - loss: 0.0017 - mean_absolute_error: 0.0263 - val_loss: 0.0073 - val_mean_absolute_error: 0.0597
# Epoch 32/75
# 129/129 [==============================] - 21s 164ms/step - loss: 0.0017 - mean_absolute_error: 0.0261 - val_loss: 0.0066 - val_mean_absolute_error: 0.0566
# Epoch 33/75
# 129/129 [==============================] - 22s 173ms/step - loss: 0.0017 - mean_absolute_error: 0.0262 - val_loss: 0.0069 - val_mean_absolute_error: 0.0577
# Epoch 34/75
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0017 - mean_absolute_error: 0.0263 - val_loss: 0.0074 - val_mean_absolute_error: 0.0597
# Epoch 35/75
# 129/129 [==============================] - 19s 149ms/step - loss: 0.0017 - mean_absolute_error: 0.0261 - val_loss: 0.0068 - val_mean_absolute_error: 0.0579
# Epoch 36/75
# 129/129 [==============================] - 21s 167ms/step - loss: 0.0016 - mean_absolute_error: 0.0254 - val_loss: 0.0069 - val_mean_absolute_error: 0.0582
# Epoch 37/75
# 129/129 [==============================] - 19s 150ms/step - loss: 0.0016 - mean_absolute_error: 0.0253 - val_loss: 0.0073 - val_mean_absolute_error: 0.0600
# Epoch 38/75
# 129/129 [==============================] - 20s 158ms/step - loss: 0.0015 - mean_absolute_error: 0.0251 - val_loss: 0.0072 - val_mean_absolute_error: 0.0593
# Epoch 39/75
# 129/129 [==============================] - 21s 159ms/step - loss: 0.0015 - mean_absolute_error: 0.0247 - val_loss: 0.0075 - val_mean_absolute_error: 0.0598
# Epoch 40/75
# 129/129 [==============================] - 20s 155ms/step - loss: 0.0016 - mean_absolute_error: 0.0252 - val_loss: 0.0077 - val_mean_absolute_error: 0.0622
# Epoch 41/75
# 122/129 [===========================>..] - ETA: 1s - loss: 0.0015 - mean_absolute_error: 0.0245
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-49c076dd6059> in <cell line: 6>()
#       4 model.compile(optimizer='adam', loss='mse',metrics=[tf.metrics.MeanAbsoluteError()])
#       5
# ----> 6 history = model.fit(x_train, y_train, epochs=epoch, validation_data=(x_test, y_test))
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
future = model.predict_generator(x_test)

# %%
print(future.shape)

# %%
future= np.reshape(future, (1296*3, 7))

# %%
future = pd.DataFrame(future)

# %%
future= normalize.inverse_transform(future)

# %%
future = pd.DataFrame(future)

# %%
future

# %%
future.shape

# %%
y_test.shape

# %%
actual = np.reshape(y_test, (1296*3, 7))

# %%
actual= pd.DataFrame(actual)

# %%
actual = normalize.inverse_transform(actual)

# %%
actual= pd.DataFrame(actual)

# %%
actual

# %%
actual.shape

# %%
df_compare = pd.DataFrame()

# %%
df_compare['pm10'] = actual[0]
df_compare['pm10_pred'] = future[0]
df_compare['pm25'] = actual[1]
df_compare['pm25_pred'] = future[1]
df_compare['co'] = actual[2]
df_compare['co_pred'] = future[2]
df_compare['no2'] = actual[3]
df_compare['no2_pred'] = future[3]
df_compare['o3'] = actual[4]
df_compare['o3_pred'] =future[4]
df_compare['so2'] = actual[5]
df_compare['so2_pred'] = future[5]
df_compare['aqi'] = actual[6]
df_compare['aqi_pred'] = future[6]

# %%
df_compare

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20,10)
mpl.rcParams['axes.grid'] = False
df_compare[['aqi', 'aqi_pred']][::15].plot()
df_compare[['pm10', 'pm10_pred']][::15].plot()
df_compare[['pm25', 'pm25_pred']][::15].plot()
df_compare[['o3', 'o3_pred']][::15].plot()
df_compare[['so2', 'so2_pred']][::15].plot()
df_compare[['no2', 'no2_pred']][::15].plot()
df_compare[['co', 'co_pred']][::15].plot()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score, explained_variance_score, max_error
from sklearn.metrics import median_absolute_error, mean_squared_log_error

indicator = ["aqi",'pm10', 'pm25', 'o3', 'so2', 'no2', 'co']
for i in indicator:
    rmse = mean_squared_error(df_compare[f'{i}'], df_compare[f'{i}_pred'], squared=False)
    mse = mean_squared_error(df_compare[f'{i}'], df_compare[f'{i}_pred'])
    mae = mean_absolute_error(df_compare[f'{i}'], df_compare[f'{i}_pred'])
    mape = mean_absolute_percentage_error(df_compare[f'{i}'], df_compare[f'{i}_pred'])


    print(f'{i} ----> RMSE: {rmse} ; MSE: {mse} ; MAE: {mae} ; MAPE: {mape}  \n')
